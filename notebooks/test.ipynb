# %%
import pandas as pd
import pyarrow.parquet as pq
from pathlib import Path

# %%
path = "/home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1/meta/episodes/chunk-000/file-000.parquet"

# 1. Read with 'dtype_backend="pyarrow"' to handle nested list columns without crashing
df = pd.read_parquet(path, engine='pyarrow', dtype_backend='pyarrow')

# %%
for col in df.columns:
    print(f"{col}: {df[col].dtype}")
# Out:
# stats/observation.images.zed2i_left/q10: list<element: list<element: list<element: double>>>[pyarrow]
# stats/episode_index/q99: list<element: double>[pyarrow]
# stats/timestamp/min: list<element: double>[pyarrow]
# stats/frame_index/std: list<element: double>[pyarrow]
# stats/frame_index/q90: list<element: double>[pyarrow]
# stats/task_index/std: list<element: double>[pyarrow]
# stats/frame_index/count: list<element: int64>[pyarrow]
# stats/observation.images.zed2i_left/q99: list<element: list<element: list<element: double>>>[pyarrow]
# stats/observation.images.zed2i_right/count: list<element: int64>[pyarrow]
# stats/action/mean: list<element: double>[pyarrow]
# stats/observation.state/max: list<element: double>[pyarrow]
# stats/observation.images.zedm_right/count: list<element: int64>[pyarrow]
# stats/observation.images.zedm_left/max: list<element: list<element: list<element: double>>>[pyarrow]
# stats/task_index/q01: list<element: double>[pyarrow]
# data/file_index: int64[pyarrow]
# stats/episode_index/std: list<element: double>[pyarrow]
# stats/observation.images.zedm_left/q50: list<element: list<element: list<element: double>>>[pyarrow]
# stats/observation.images.zed2i_left/max: list<element: list<element: list<element: double>>>[pyarrow]
# stats/observation.images.zedm_right/q10: list<element: list<element: list<element: double>>>[pyarrow]
# dataset_from_index: int64[pyarrow]
# stats/observation.images.zedm_left/min: list<element: list<element: list<element: double>>>[pyarrow]
# stats/action/count: list<element: int64>[pyarrow]
# stats/observation.images.zed2i_right/max: list<element: list<element: list<element: double>>>[pyarrow]
# stats/observation.images.zedm_left/q01: list<element: list<element: list<element: double>>>[pyarrow]
# stats/observation.images.zedm_left/q90: list<element: list<element: list<element: double>>>[pyarrow]
# stats/index/mean: list<element: double>[pyarrow]
# stats/observation.state/std: list<element: double>[pyarrow]
# videos/observation.images.zedm_left/from_timestamp: double[pyarrow]
# stats/observation.images.zedm_right/q99: list<element: list<element: list<element: double>>>[pyarrow]
# stats/timestamp/max: list<element: double>[pyarrow]
# stats/action/q01: list<element: double>[pyarrow]
# stats/timestamp/q90: list<element: double>[pyarrow]
# videos/observation.images.zed2i_right/from_timestamp: double[pyarrow]
# stats/episode_index/mean: list<element: double>[pyarrow]
# meta/episodes/chunk_index: int64[pyarrow]
# stats/observation.images.zed2i_left/q90: list<element: list<element: list<element: double>>>[pyarrow]
# stats/task_index/q10: list<element: double>[pyarrow]
# stats/episode_index/q50: list<element: double>[pyarrow]
# stats/index/count: list<element: int64>[pyarrow]
# stats/observation.state/q99: list<element: double>[pyarrow]
# stats/index/q99: list<element: double>[pyarrow]
# stats/observation.images.zed2i_right/q99: list<element: list<element: list<element: double>>>[pyarrow]
# videos/observation.images.zedm_right/file_index: int64[pyarrow]
# stats/action/min: list<element: double>[pyarrow]
# stats/task_index/min: list<element: int64>[pyarrow]
# stats/observation.state/mean: list<element: double>[pyarrow]
# stats/action/q50: list<element: double>[pyarrow]
# videos/observation.images.zed2i_right/to_timestamp: double[pyarrow]
# dataset_to_index: int64[pyarrow]
# data/chunk_index: int64[pyarrow]
# stats/action/max: list<element: double>[pyarrow]
# stats/timestamp/q01: list<element: double>[pyarrow]
# stats/frame_index/max: list<element: int64>[pyarrow]
# stats/frame_index/q10: list<element: double>[pyarrow]
# stats/episode_index/min: list<element: int64>[pyarrow]
# stats/observation.images.zed2i_left/q50: list<element: list<element: list<element: double>>>[pyarrow]
# stats/frame_index/mean: list<element: double>[pyarrow]
# stats/timestamp/q99: list<element: double>[pyarrow]
# stats/task_index/max: list<element: int64>[pyarrow]
# stats/frame_index/q50: list<element: double>[pyarrow]
# videos/observation.images.zedm_right/from_timestamp: double[pyarrow]
# stats/task_index/q90: list<element: double>[pyarrow]
# stats/timestamp/mean: list<element: double>[pyarrow]
# stats/task_index/q50: list<element: double>[pyarrow]
# stats/action/q99: list<element: double>[pyarrow]
# stats/episode_index/q90: list<element: double>[pyarrow]
# videos/observation.images.zedm_left/chunk_index: int64[pyarrow]
# stats/frame_index/q99: list<element: double>[pyarrow]
# stats/timestamp/std: list<element: double>[pyarrow]
# stats/observation.state/count: list<element: int64>[pyarrow]
# stats/observation.images.zed2i_left/mean: list<element: list<element: list<element: double>>>[pyarrow]
# stats/observation.state/q90: list<element: double>[pyarrow]
# stats/observation.state/min: list<element: double>[pyarrow]
# stats/index/max: list<element: int64>[pyarrow]
# stats/observation.images.zedm_right/q01: list<element: list<element: list<element: double>>>[pyarrow]
# stats/observation.state/q50: list<element: double>[pyarrow]
# videos/observation.images.zed2i_left/from_timestamp: double[pyarrow]
# stats/task_index/mean: list<element: double>[pyarrow]
# videos/observation.images.zedm_right/chunk_index: int64[pyarrow]
# length: int64[pyarrow]
# stats/observation.images.zed2i_right/q50: list<element: list<element: list<element: double>>>[pyarrow]
# videos/observation.images.zed2i_right/file_index: int64[pyarrow]
# stats/timestamp/count: list<element: int64>[pyarrow]
# stats/observation.images.zed2i_right/std: list<element: list<element: list<element: double>>>[pyarrow]
# stats/observation.images.zed2i_right/q10: list<element: list<element: list<element: double>>>[pyarrow]
# stats/observation.images.zedm_right/max: list<element: list<element: list<element: double>>>[pyarrow]
# stats/task_index/q99: list<element: double>[pyarrow]
# videos/observation.images.zed2i_left/file_index: int64[pyarrow]
# stats/observation.images.zed2i_left/q01: list<element: list<element: list<element: double>>>[pyarrow]
# videos/observation.images.zed2i_left/chunk_index: int64[pyarrow]
# stats/observation.images.zed2i_left/count: list<element: int64>[pyarrow]
# stats/observation.images.zed2i_right/mean: list<element: list<element: list<element: double>>>[pyarrow]
# stats/observation.images.zed2i_right/q90: list<element: list<element: list<element: double>>>[pyarrow]
# meta/episodes/file_index: int64[pyarrow]
# stats/task_index/count: list<element: int64>[pyarrow]
# stats/index/std: list<element: double>[pyarrow]
# stats/observation.images.zed2i_right/min: list<element: list<element: list<element: double>>>[pyarrow]
# stats/index/min: list<element: int64>[pyarrow]
# videos/observation.images.zedm_left/to_timestamp: double[pyarrow]
# episode_index: int64[pyarrow]
# stats/action/std: list<element: double>[pyarrow]
# stats/observation.images.zed2i_right/q01: list<element: list<element: list<element: double>>>[pyarrow]
# stats/index/q10: list<element: double>[pyarrow]
# videos/observation.images.zedm_right/to_timestamp: double[pyarrow]
# stats/observation.state/q01: list<element: double>[pyarrow]
# stats/episode_index/max: list<element: int64>[pyarrow]
# stats/observation.images.zedm_right/mean: list<element: list<element: list<element: double>>>[pyarrow]
# stats/observation.images.zedm_right/min: list<element: list<element: list<element: double>>>[pyarrow]
# stats/observation.images.zedm_right/std: list<element: list<element: list<element: double>>>[pyarrow]
# videos/observation.images.zedm_left/file_index: int64[pyarrow]
# stats/frame_index/min: list<element: int64>[pyarrow]
# videos/observation.images.zed2i_left/to_timestamp: double[pyarrow]
# stats/timestamp/q10: list<element: double>[pyarrow]
# stats/episode_index/count: list<element: int64>[pyarrow]
# stats/action/q10: list<element: double>[pyarrow]
# tasks: list<element: string>[pyarrow]
# stats/timestamp/q50: list<element: double>[pyarrow]
# stats/frame_index/q01: list<element: double>[pyarrow]
# stats/observation.images.zedm_left/std: list<element: list<element: list<element: double>>>[pyarrow]
# stats/episode_index/q01: list<element: double>[pyarrow]
# stats/observation.images.zedm_left/q99: list<element: list<element: list<element: double>>>[pyarrow]
# stats/observation.images.zedm_left/q10: list<element: list<element: list<element: double>>>[pyarrow]
# stats/observation.images.zedm_left/mean: list<element: list<element: list<element: double>>>[pyarrow]
# stats/index/q01: list<element: double>[pyarrow]
# stats/action/q90: list<element: double>[pyarrow]
# stats/observation.state/q10: list<element: double>[pyarrow]
# videos/observation.images.zed2i_right/chunk_index: int64[pyarrow]
# stats/observation.images.zedm_right/q50: list<element: list<element: list<element: double>>>[pyarrow]
# stats/index/q50: list<element: double>[pyarrow]
# stats/observation.images.zedm_left/count: list<element: int64>[pyarrow]
# stats/observation.images.zedm_right/q90: list<element: list<element: list<element: double>>>[pyarrow]
# stats/index/q90: list<element: double>[pyarrow]
# stats/observation.images.zed2i_left/std: list<element: list<element: list<element: double>>>[pyarrow]
# stats/episode_index/q10: list<element: double>[pyarrow]
# stats/observation.images.zed2i_left/min: list<element: list<element: list<element: double>>>[pyarrow]

# %%
dataset_path = Path("/home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3")  # Update this path
meta_files = list(dataset_path.glob("meta/episodes/**/*.parquet"))

n_cols_updated = 0

for p in meta_files:
    # 1. Read with 'dtype_backend="pyarrow"' to handle nested list columns without crashing
    df = pd.read_parquet(p, engine='pyarrow', dtype_backend='pyarrow')

    # 2. Iterate and cast columns
    for col in df.columns:
        if col.endswith("_index"):
            # We cast to "int64[pyarrow]" to match the backend we used for loading
            # (This is the PyArrow equivalent of the "Int64" nullable type)
            print(f"{p}: Casting {col} to int64[pyarrow]")
            df[col] = df[col].astype("int64[pyarrow]")
            n_cols_updated += 1
    # 3. Save it back to disk
    # Note: This overwrites the original file. Change 'path' if you want to save a copy.
    df.to_parquet(p, engine='pyarrow')

print(f"Updated {n_cols_updated} columns in {len(meta_files)} files.")
print("Done! Columns cast and file saved.")
# Out:
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-003.parquet: Casting data/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-003.parquet: Casting episode_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-003.parquet: Casting meta/episodes/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-003.parquet: Casting data/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-003.parquet: Casting dataset_to_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-003.parquet: Casting meta/episodes/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-003.parquet: Casting dataset_from_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-003.parquet: Casting videos/observation.images.zed2i_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-003.parquet: Casting videos/observation.images.zed2i_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-003.parquet: Casting videos/observation.images.zed2i_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-003.parquet: Casting videos/observation.images.zed2i_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-003.parquet: Casting videos/observation.images.zedm_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-003.parquet: Casting videos/observation.images.zedm_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-003.parquet: Casting videos/observation.images.zedm_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-003.parquet: Casting videos/observation.images.zedm_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-008.parquet: Casting episode_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-008.parquet: Casting meta/episodes/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-008.parquet: Casting meta/episodes/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-008.parquet: Casting dataset_from_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-008.parquet: Casting dataset_to_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-008.parquet: Casting data/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-008.parquet: Casting data/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-008.parquet: Casting videos/observation.images.zed2i_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-008.parquet: Casting videos/observation.images.zed2i_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-008.parquet: Casting videos/observation.images.zed2i_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-008.parquet: Casting videos/observation.images.zed2i_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-008.parquet: Casting videos/observation.images.zedm_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-008.parquet: Casting videos/observation.images.zedm_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-008.parquet: Casting videos/observation.images.zedm_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-008.parquet: Casting videos/observation.images.zedm_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-000.parquet: Casting data/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-000.parquet: Casting dataset_from_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-000.parquet: Casting meta/episodes/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-000.parquet: Casting videos/observation.images.zedm_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-000.parquet: Casting dataset_to_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-000.parquet: Casting data/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-000.parquet: Casting videos/observation.images.zedm_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-000.parquet: Casting videos/observation.images.zedm_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-000.parquet: Casting videos/observation.images.zed2i_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-000.parquet: Casting videos/observation.images.zed2i_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-000.parquet: Casting videos/observation.images.zed2i_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-000.parquet: Casting meta/episodes/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-000.parquet: Casting episode_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-000.parquet: Casting videos/observation.images.zedm_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-000.parquet: Casting videos/observation.images.zed2i_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-018.parquet: Casting data/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-018.parquet: Casting dataset_to_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-018.parquet: Casting meta/episodes/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-018.parquet: Casting episode_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-018.parquet: Casting data/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-018.parquet: Casting meta/episodes/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-018.parquet: Casting dataset_from_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-018.parquet: Casting videos/observation.images.zed2i_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-018.parquet: Casting videos/observation.images.zed2i_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-018.parquet: Casting videos/observation.images.zed2i_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-018.parquet: Casting videos/observation.images.zed2i_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-018.parquet: Casting videos/observation.images.zedm_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-018.parquet: Casting videos/observation.images.zedm_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-018.parquet: Casting videos/observation.images.zedm_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-018.parquet: Casting videos/observation.images.zedm_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-010.parquet: Casting episode_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-010.parquet: Casting meta/episodes/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-010.parquet: Casting dataset_from_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-010.parquet: Casting data/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-010.parquet: Casting meta/episodes/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-010.parquet: Casting dataset_to_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-010.parquet: Casting data/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-010.parquet: Casting videos/observation.images.zed2i_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-010.parquet: Casting videos/observation.images.zed2i_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-010.parquet: Casting videos/observation.images.zed2i_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-010.parquet: Casting videos/observation.images.zed2i_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-010.parquet: Casting videos/observation.images.zedm_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-010.parquet: Casting videos/observation.images.zedm_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-010.parquet: Casting videos/observation.images.zedm_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-010.parquet: Casting videos/observation.images.zedm_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-007.parquet: Casting dataset_from_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-007.parquet: Casting data/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-007.parquet: Casting data/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-007.parquet: Casting meta/episodes/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-007.parquet: Casting dataset_to_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-007.parquet: Casting episode_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-007.parquet: Casting meta/episodes/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-007.parquet: Casting videos/observation.images.zed2i_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-007.parquet: Casting videos/observation.images.zed2i_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-007.parquet: Casting videos/observation.images.zed2i_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-007.parquet: Casting videos/observation.images.zed2i_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-007.parquet: Casting videos/observation.images.zedm_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-007.parquet: Casting videos/observation.images.zedm_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-007.parquet: Casting videos/observation.images.zedm_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-007.parquet: Casting videos/observation.images.zedm_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-011.parquet: Casting meta/episodes/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-011.parquet: Casting data/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-011.parquet: Casting dataset_to_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-011.parquet: Casting data/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-011.parquet: Casting episode_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-011.parquet: Casting dataset_from_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-011.parquet: Casting meta/episodes/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-011.parquet: Casting videos/observation.images.zed2i_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-011.parquet: Casting videos/observation.images.zed2i_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-011.parquet: Casting videos/observation.images.zed2i_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-011.parquet: Casting videos/observation.images.zed2i_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-011.parquet: Casting videos/observation.images.zedm_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-011.parquet: Casting videos/observation.images.zedm_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-011.parquet: Casting videos/observation.images.zedm_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-011.parquet: Casting videos/observation.images.zedm_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-014.parquet: Casting meta/episodes/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-014.parquet: Casting data/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-014.parquet: Casting dataset_to_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-014.parquet: Casting data/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-014.parquet: Casting dataset_from_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-014.parquet: Casting episode_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-014.parquet: Casting meta/episodes/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-014.parquet: Casting videos/observation.images.zed2i_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-014.parquet: Casting videos/observation.images.zed2i_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-014.parquet: Casting videos/observation.images.zed2i_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-014.parquet: Casting videos/observation.images.zed2i_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-014.parquet: Casting videos/observation.images.zedm_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-014.parquet: Casting videos/observation.images.zedm_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-014.parquet: Casting videos/observation.images.zedm_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-014.parquet: Casting videos/observation.images.zedm_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-005.parquet: Casting dataset_from_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-005.parquet: Casting meta/episodes/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-005.parquet: Casting meta/episodes/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-005.parquet: Casting data/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-005.parquet: Casting data/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-005.parquet: Casting episode_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-005.parquet: Casting dataset_to_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-005.parquet: Casting videos/observation.images.zed2i_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-005.parquet: Casting videos/observation.images.zed2i_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-005.parquet: Casting videos/observation.images.zed2i_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-005.parquet: Casting videos/observation.images.zed2i_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-005.parquet: Casting videos/observation.images.zedm_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-005.parquet: Casting videos/observation.images.zedm_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-005.parquet: Casting videos/observation.images.zedm_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-005.parquet: Casting videos/observation.images.zedm_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-019.parquet: Casting data/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-019.parquet: Casting meta/episodes/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-019.parquet: Casting data/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-019.parquet: Casting dataset_from_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-019.parquet: Casting meta/episodes/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-019.parquet: Casting episode_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-019.parquet: Casting dataset_to_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-019.parquet: Casting videos/observation.images.zed2i_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-019.parquet: Casting videos/observation.images.zed2i_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-019.parquet: Casting videos/observation.images.zed2i_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-019.parquet: Casting videos/observation.images.zed2i_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-019.parquet: Casting videos/observation.images.zedm_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-019.parquet: Casting videos/observation.images.zedm_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-019.parquet: Casting videos/observation.images.zedm_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-019.parquet: Casting videos/observation.images.zedm_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-013.parquet: Casting videos/observation.images.zed2i_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-013.parquet: Casting dataset_to_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-013.parquet: Casting videos/observation.images.zedm_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-013.parquet: Casting meta/episodes/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-013.parquet: Casting videos/observation.images.zedm_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-013.parquet: Casting data/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-013.parquet: Casting videos/observation.images.zedm_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-013.parquet: Casting videos/observation.images.zed2i_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-013.parquet: Casting meta/episodes/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-013.parquet: Casting episode_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-013.parquet: Casting data/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-013.parquet: Casting videos/observation.images.zed2i_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-013.parquet: Casting dataset_from_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-013.parquet: Casting videos/observation.images.zed2i_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-013.parquet: Casting videos/observation.images.zedm_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-021.parquet: Casting episode_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-021.parquet: Casting dataset_to_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-021.parquet: Casting data/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-021.parquet: Casting meta/episodes/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-021.parquet: Casting meta/episodes/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-021.parquet: Casting data/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-021.parquet: Casting dataset_from_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-021.parquet: Casting videos/observation.images.zed2i_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-021.parquet: Casting videos/observation.images.zed2i_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-021.parquet: Casting videos/observation.images.zed2i_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-021.parquet: Casting videos/observation.images.zed2i_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-021.parquet: Casting videos/observation.images.zedm_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-021.parquet: Casting videos/observation.images.zedm_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-021.parquet: Casting videos/observation.images.zedm_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-021.parquet: Casting videos/observation.images.zedm_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-001.parquet: Casting videos/observation.images.zedm_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-001.parquet: Casting videos/observation.images.zed2i_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-001.parquet: Casting videos/observation.images.zedm_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-001.parquet: Casting videos/observation.images.zedm_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-001.parquet: Casting meta/episodes/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-001.parquet: Casting videos/observation.images.zedm_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-001.parquet: Casting meta/episodes/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-001.parquet: Casting videos/observation.images.zed2i_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-001.parquet: Casting videos/observation.images.zed2i_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-001.parquet: Casting dataset_from_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-001.parquet: Casting videos/observation.images.zed2i_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-001.parquet: Casting episode_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-001.parquet: Casting dataset_to_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-001.parquet: Casting data/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-001.parquet: Casting data/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-017.parquet: Casting meta/episodes/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-017.parquet: Casting data/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-017.parquet: Casting dataset_from_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-017.parquet: Casting episode_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-017.parquet: Casting dataset_to_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-017.parquet: Casting data/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-017.parquet: Casting meta/episodes/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-017.parquet: Casting videos/observation.images.zed2i_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-017.parquet: Casting videos/observation.images.zed2i_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-017.parquet: Casting videos/observation.images.zed2i_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-017.parquet: Casting videos/observation.images.zed2i_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-017.parquet: Casting videos/observation.images.zedm_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-017.parquet: Casting videos/observation.images.zedm_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-017.parquet: Casting videos/observation.images.zedm_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-017.parquet: Casting videos/observation.images.zedm_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-006.parquet: Casting meta/episodes/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-006.parquet: Casting data/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-006.parquet: Casting data/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-006.parquet: Casting dataset_from_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-006.parquet: Casting dataset_to_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-006.parquet: Casting episode_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-006.parquet: Casting meta/episodes/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-006.parquet: Casting videos/observation.images.zed2i_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-006.parquet: Casting videos/observation.images.zed2i_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-006.parquet: Casting videos/observation.images.zed2i_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-006.parquet: Casting videos/observation.images.zed2i_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-006.parquet: Casting videos/observation.images.zedm_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-006.parquet: Casting videos/observation.images.zedm_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-006.parquet: Casting videos/observation.images.zedm_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-006.parquet: Casting videos/observation.images.zedm_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-012.parquet: Casting meta/episodes/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-012.parquet: Casting meta/episodes/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-012.parquet: Casting dataset_from_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-012.parquet: Casting episode_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-012.parquet: Casting dataset_to_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-012.parquet: Casting data/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-012.parquet: Casting data/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-012.parquet: Casting videos/observation.images.zed2i_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-012.parquet: Casting videos/observation.images.zed2i_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-012.parquet: Casting videos/observation.images.zed2i_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-012.parquet: Casting videos/observation.images.zed2i_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-012.parquet: Casting videos/observation.images.zedm_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-012.parquet: Casting videos/observation.images.zedm_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-012.parquet: Casting videos/observation.images.zedm_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-012.parquet: Casting videos/observation.images.zedm_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-004.parquet: Casting meta/episodes/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-004.parquet: Casting dataset_to_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-004.parquet: Casting data/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-004.parquet: Casting data/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-004.parquet: Casting meta/episodes/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-004.parquet: Casting dataset_from_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-004.parquet: Casting episode_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-004.parquet: Casting videos/observation.images.zed2i_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-004.parquet: Casting videos/observation.images.zed2i_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-004.parquet: Casting videos/observation.images.zed2i_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-004.parquet: Casting videos/observation.images.zed2i_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-004.parquet: Casting videos/observation.images.zedm_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-004.parquet: Casting videos/observation.images.zedm_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-004.parquet: Casting videos/observation.images.zedm_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-004.parquet: Casting videos/observation.images.zedm_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-009.parquet: Casting episode_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-009.parquet: Casting dataset_to_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-009.parquet: Casting data/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-009.parquet: Casting dataset_from_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-009.parquet: Casting meta/episodes/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-009.parquet: Casting meta/episodes/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-009.parquet: Casting data/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-009.parquet: Casting videos/observation.images.zed2i_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-009.parquet: Casting videos/observation.images.zed2i_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-009.parquet: Casting videos/observation.images.zed2i_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-009.parquet: Casting videos/observation.images.zed2i_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-009.parquet: Casting videos/observation.images.zedm_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-009.parquet: Casting videos/observation.images.zedm_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-009.parquet: Casting videos/observation.images.zedm_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-009.parquet: Casting videos/observation.images.zedm_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-002.parquet: Casting meta/episodes/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-002.parquet: Casting dataset_from_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-002.parquet: Casting dataset_to_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-002.parquet: Casting data/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-002.parquet: Casting meta/episodes/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-002.parquet: Casting episode_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-002.parquet: Casting data/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-002.parquet: Casting videos/observation.images.zed2i_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-002.parquet: Casting videos/observation.images.zed2i_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-002.parquet: Casting videos/observation.images.zed2i_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-002.parquet: Casting videos/observation.images.zed2i_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-002.parquet: Casting videos/observation.images.zedm_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-002.parquet: Casting videos/observation.images.zedm_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-002.parquet: Casting videos/observation.images.zedm_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-002.parquet: Casting videos/observation.images.zedm_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-015.parquet: Casting meta/episodes/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-015.parquet: Casting episode_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-015.parquet: Casting dataset_from_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-015.parquet: Casting data/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-015.parquet: Casting dataset_to_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-015.parquet: Casting data/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-015.parquet: Casting meta/episodes/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-015.parquet: Casting videos/observation.images.zed2i_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-015.parquet: Casting videos/observation.images.zed2i_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-015.parquet: Casting videos/observation.images.zed2i_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-015.parquet: Casting videos/observation.images.zed2i_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-015.parquet: Casting videos/observation.images.zedm_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-015.parquet: Casting videos/observation.images.zedm_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-015.parquet: Casting videos/observation.images.zedm_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-015.parquet: Casting videos/observation.images.zedm_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-020.parquet: Casting episode_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-020.parquet: Casting data/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-020.parquet: Casting meta/episodes/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-020.parquet: Casting data/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-020.parquet: Casting meta/episodes/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-020.parquet: Casting dataset_from_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-020.parquet: Casting dataset_to_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-020.parquet: Casting videos/observation.images.zed2i_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-020.parquet: Casting videos/observation.images.zed2i_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-020.parquet: Casting videos/observation.images.zed2i_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-020.parquet: Casting videos/observation.images.zed2i_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-020.parquet: Casting videos/observation.images.zedm_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-020.parquet: Casting videos/observation.images.zedm_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-020.parquet: Casting videos/observation.images.zedm_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-020.parquet: Casting videos/observation.images.zedm_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-016.parquet: Casting episode_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-016.parquet: Casting meta/episodes/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-016.parquet: Casting meta/episodes/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-016.parquet: Casting dataset_to_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-016.parquet: Casting data/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-016.parquet: Casting data/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-016.parquet: Casting dataset_from_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-016.parquet: Casting videos/observation.images.zed2i_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-016.parquet: Casting videos/observation.images.zed2i_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-016.parquet: Casting videos/observation.images.zed2i_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-016.parquet: Casting videos/observation.images.zed2i_right/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-016.parquet: Casting videos/observation.images.zedm_left/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-016.parquet: Casting videos/observation.images.zedm_left/file_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-016.parquet: Casting videos/observation.images.zedm_right/chunk_index to int64[pyarrow]
# /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-016.parquet: Casting videos/observation.images.zedm_right/file_index to int64[pyarrow]
# Updated 330 columns in 22 files.
# Done! Columns cast and file saved.

# %%
import pyarrow.parquet as pq

path1 = "/home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-0/meta/episodes/chunk-000/file-000.parquet"
path2 = "/home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1_old/meta/episodes/chunk-000/file-002.parquet"

def get_schema_dict(path):
    try:
        # Read schema only
        schema = pq.read_schema(path)
        # Create a dict of {column_name: string_representation_of_type}
        return {name: str(schema.field(name).type) for name in schema.names}
    except Exception as e:
        print(f"Error reading {path}: {e}")
        return {}

schema1 = get_schema_dict(path1)
schema2 = get_schema_dict(path2)

# Get all unique columns from both files
all_cols = sorted(set(schema1.keys()) | set(schema2.keys()))

print(f"{'Column':<50} | {'File 1 Type':<30} | {'File 2 Type':<30}")
print("-" * 116)

for col in all_cols:
    type1 = schema1.get(col, "MISSING")
    type2 = schema2.get(col, "MISSING")
    
    # Highlight differences
    if type1 != type2:
        marker = "Mismatch -> " 
    else:
        marker = ""
        
    # Optional: Print only mismatches or everything. Currently prints everything.
    print(f"{marker}{col:<38} | {type1:<30} | {type2:<30}")
# Out:
# Column                                             | File 1 Type                    | File 2 Type
# --------------------------------------------------------------------------------------------------------------------
# data/chunk_index                       | int64                          | int64
# data/file_index                        | int64                          | int64
# dataset_from_index                     | int64                          | int64
# dataset_to_index                       | int64                          | int64
# episode_index                          | int64                          | int64
# length                                 | int64                          | int64
# meta/episodes/chunk_index              | int64                          | int64
# meta/episodes/file_index               | int64                          | int64
# stats/action/count                     | list<element: int64>           | list<element: int64>
# stats/action/max                       | list<element: double>          | list<element: double>
# stats/action/mean                      | list<element: double>          | list<element: double>
# stats/action/min                       | list<element: double>          | list<element: double>
# stats/action/q01                       | list<element: double>          | list<element: double>
# stats/action/q10                       | list<element: double>          | list<element: double>
# stats/action/q50                       | list<element: double>          | list<element: double>
# stats/action/q90                       | list<element: double>          | list<element: double>
# stats/action/q99                       | list<element: double>          | list<element: double>
# stats/action/std                       | list<element: double>          | list<element: double>
# stats/episode_index/count              | list<element: int64>           | list<element: int64>
# stats/episode_index/max                | list<element: int64>           | list<element: int64>
# stats/episode_index/mean               | list<element: double>          | list<element: double>
# stats/episode_index/min                | list<element: int64>           | list<element: int64>
# stats/episode_index/q01                | list<element: double>          | list<element: double>
# stats/episode_index/q10                | list<element: double>          | list<element: double>
# stats/episode_index/q50                | list<element: double>          | list<element: double>
# stats/episode_index/q90                | list<element: double>          | list<element: double>
# stats/episode_index/q99                | list<element: double>          | list<element: double>
# stats/episode_index/std                | list<element: double>          | list<element: double>
# stats/frame_index/count                | list<element: int64>           | list<element: int64>
# stats/frame_index/max                  | list<element: int64>           | list<element: int64>
# stats/frame_index/mean                 | list<element: double>          | list<element: double>
# stats/frame_index/min                  | list<element: int64>           | list<element: int64>
# stats/frame_index/q01                  | list<element: double>          | list<element: double>
# stats/frame_index/q10                  | list<element: double>          | list<element: double>
# stats/frame_index/q50                  | list<element: double>          | list<element: double>
# stats/frame_index/q90                  | list<element: double>          | list<element: double>
# stats/frame_index/q99                  | list<element: double>          | list<element: double>
# stats/frame_index/std                  | list<element: double>          | list<element: double>
# stats/index/count                      | list<element: int64>           | list<element: int64>
# stats/index/max                        | list<element: int64>           | list<element: int64>
# stats/index/mean                       | list<element: double>          | list<element: double>
# stats/index/min                        | list<element: int64>           | list<element: int64>
# stats/index/q01                        | list<element: double>          | list<element: double>
# stats/index/q10                        | list<element: double>          | list<element: double>
# stats/index/q50                        | list<element: double>          | list<element: double>
# stats/index/q90                        | list<element: double>          | list<element: double>
# stats/index/q99                        | list<element: double>          | list<element: double>
# stats/index/std                        | list<element: double>          | list<element: double>
# stats/observation.images.zed2i_left/count | list<element: int64>           | list<element: int64>
# stats/observation.images.zed2i_left/max | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zed2i_left/mean | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zed2i_left/min | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zed2i_left/q01 | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zed2i_left/q10 | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zed2i_left/q50 | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zed2i_left/q90 | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zed2i_left/q99 | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zed2i_left/std | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zed2i_right/count | list<element: int64>           | list<element: int64>
# stats/observation.images.zed2i_right/max | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zed2i_right/mean | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zed2i_right/min | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zed2i_right/q01 | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zed2i_right/q10 | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zed2i_right/q50 | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zed2i_right/q90 | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zed2i_right/q99 | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zed2i_right/std | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zedm_left/count | list<element: int64>           | list<element: int64>
# stats/observation.images.zedm_left/max | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zedm_left/mean | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zedm_left/min | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zedm_left/q01 | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zedm_left/q10 | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zedm_left/q50 | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zedm_left/q90 | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zedm_left/q99 | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zedm_left/std | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zedm_right/count | list<element: int64>           | list<element: int64>
# stats/observation.images.zedm_right/max | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zedm_right/mean | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zedm_right/min | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zedm_right/q01 | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zedm_right/q10 | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zedm_right/q50 | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zedm_right/q90 | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zedm_right/q99 | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.images.zedm_right/std | list<element: list<element: list<element: double>>> | list<element: list<element: list<element: double>>>
# stats/observation.state/count          | list<element: int64>           | list<element: int64>
# stats/observation.state/max            | list<element: double>          | list<element: double>
# stats/observation.state/mean           | list<element: double>          | list<element: double>
# stats/observation.state/min            | list<element: double>          | list<element: double>
# stats/observation.state/q01            | list<element: double>          | list<element: double>
# stats/observation.state/q10            | list<element: double>          | list<element: double>
# stats/observation.state/q50            | list<element: double>          | list<element: double>
# stats/observation.state/q90            | list<element: double>          | list<element: double>
# stats/observation.state/q99            | list<element: double>          | list<element: double>
# stats/observation.state/std            | list<element: double>          | list<element: double>
# stats/task_index/count                 | list<element: int64>           | list<element: int64>
# stats/task_index/max                   | list<element: int64>           | list<element: int64>
# stats/task_index/mean                  | list<element: double>          | list<element: double>
# stats/task_index/min                   | list<element: int64>           | list<element: int64>
# stats/task_index/q01                   | list<element: double>          | list<element: double>
# stats/task_index/q10                   | list<element: double>          | list<element: double>
# stats/task_index/q50                   | list<element: double>          | list<element: double>
# stats/task_index/q90                   | list<element: double>          | list<element: double>
# stats/task_index/q99                   | list<element: double>          | list<element: double>
# stats/task_index/std                   | list<element: double>          | list<element: double>
# stats/timestamp/count                  | list<element: int64>           | list<element: int64>
# stats/timestamp/max                    | list<element: double>          | list<element: double>
# stats/timestamp/mean                   | list<element: double>          | list<element: double>
# stats/timestamp/min                    | list<element: double>          | list<element: double>
# stats/timestamp/q01                    | list<element: double>          | list<element: double>
# stats/timestamp/q10                    | list<element: double>          | list<element: double>
# stats/timestamp/q50                    | list<element: double>          | list<element: double>
# stats/timestamp/q90                    | list<element: double>          | list<element: double>
# stats/timestamp/q99                    | list<element: double>          | list<element: double>
# stats/timestamp/std                    | list<element: double>          | list<element: double>
# tasks                                  | list<element: string>          | list<element: string>
# Mismatch -> videos/observation.images.zed2i_left/chunk_index | int64                          | double
# Mismatch -> videos/observation.images.zed2i_left/file_index | int64                          | double
# videos/observation.images.zed2i_left/from_timestamp | double                         | double
# videos/observation.images.zed2i_left/to_timestamp | double                         | double
# Mismatch -> videos/observation.images.zed2i_right/chunk_index | int64                          | double
# Mismatch -> videos/observation.images.zed2i_right/file_index | int64                          | double
# videos/observation.images.zed2i_right/from_timestamp | double                         | double
# videos/observation.images.zed2i_right/to_timestamp | double                         | double
# Mismatch -> videos/observation.images.zedm_left/chunk_index | int64                          | double
# Mismatch -> videos/observation.images.zedm_left/file_index | int64                          | double
# videos/observation.images.zedm_left/from_timestamp | double                         | double
# videos/observation.images.zedm_left/to_timestamp | double                         | double
# Mismatch -> videos/observation.images.zedm_right/chunk_index | int64                          | double
# Mismatch -> videos/observation.images.zedm_right/file_index | int64                          | double
# videos/observation.images.zedm_right/from_timestamp | double                         | double
# videos/observation.images.zedm_right/to_timestamp | double                         | double

# %%
for i in range(0, 22):
    path1 = f"/home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-0/meta/episodes/chunk-000/file-000.parquet"
    path2 = f"/home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3/meta/episodes/chunk-000/file-{i:03d}.parquet"
    
    schema1 = get_schema_dict(path1)
    schema2 = get_schema_dict(path2)

    all_cols = sorted(set(schema1.keys()) | set(schema2.keys()))

    for col in all_cols:
        type1 = schema1.get(col, "MISSING")
        type2 = schema2.get(col, "MISSING")

        if type1 != type2:
            marker = "Mismatch -> "
            print(f"{path2}: {marker}{col:<38} | {type1:<30} | {type2:<30}")
        else:
            marker = ""

# %%
import pandas as pd
from pathlib import Path

# Path to your dataset's episode metadata files
dataset_path = Path("/home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1")  # Update this path
meta_files = list(dataset_path.glob("meta/episodes/**/*.parquet"))

for p in meta_files:
    # Read with pyarrow backend (which handles the complex types)
    df = pd.read_parquet(p, dtype_backend="pyarrow")
    
    # Write back (pandas will infer standard schema from the data)
    df.to_parquet(p)
    print(f"Fixed {p}")
# Out:
# Fixed /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1/meta/episodes/chunk-000/file-003.parquet
# Fixed /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1/meta/episodes/chunk-000/file-008.parquet
# Fixed /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1/meta/episodes/chunk-000/file-000.parquet
# Fixed /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1/meta/episodes/chunk-000/file-018.parquet
# Fixed /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1/meta/episodes/chunk-000/file-010.parquet
# Fixed /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1/meta/episodes/chunk-000/file-007.parquet
# Fixed /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1/meta/episodes/chunk-000/file-011.parquet
# Fixed /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1/meta/episodes/chunk-000/file-014.parquet
# Fixed /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1/meta/episodes/chunk-000/file-005.parquet
# Fixed /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1/meta/episodes/chunk-000/file-019.parquet
# Fixed /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1/meta/episodes/chunk-000/file-013.parquet
# Fixed /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1/meta/episodes/chunk-000/file-021.parquet
# Fixed /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1/meta/episodes/chunk-000/file-001.parquet
# Fixed /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1/meta/episodes/chunk-000/file-017.parquet
# Fixed /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1/meta/episodes/chunk-000/file-006.parquet
# Fixed /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1/meta/episodes/chunk-000/file-012.parquet
# Fixed /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1/meta/episodes/chunk-000/file-004.parquet
# Fixed /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1/meta/episodes/chunk-000/file-009.parquet
# Fixed /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1/meta/episodes/chunk-000/file-002.parquet
# Fixed /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1/meta/episodes/chunk-000/file-015.parquet
# Fixed /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1/meta/episodes/chunk-000/file-020.parquet
# Fixed /home/finn/.cache/huggingface/lerobot/F-Fer/ur-task3-1/meta/episodes/chunk-000/file-016.parquet
